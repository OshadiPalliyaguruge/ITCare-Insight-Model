# %% [markdown]
# #### Imports

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer

# %% [markdown]
# #### Load question and answer dataset

# %%
dataset = "New dataset\\incident_report_q&a.csv"
df = pd.read_csv(dataset, encoding='latin1') # if csv file in different directory add with correct path

# %% [markdown]
# #### Explore nature of dataset

# %%
# Print first 5 rows  
print(df.head(),"\n")
#see last 5 rows 
print(df.tail(),"\n")

print(df.shape) #see number of rows and columns
num_rows = df.shape[0]
print("No of Rows: " + str(df.shape[0])+"\n")
num_columns = df.shape[1]
print("Number of columns in the dataset:", num_columns,"\n")
# Out:
#                       Summary                         Resolution
# 0    asycuda issue 6 one user    cleared thinapp browder history
# 1     email service available       outlookemail profile created
# 2     oracle issue 7 one user  refreshed session cleared browser
# 3  pc related issues  airport                       payment done
# 4                 btp working         printer emulator restarted
#
#                                     Summary  \
# 98047           network printer working cak
# 98048  printer issue airport  laser network
# 98049                         email working
# 98050                       linemax working
# 98051                          sara working
#
#                                               Resolution
# 98047       printer ip checked fixed static ip 102363692
# 98048                                    currently issue
# 98049  cdmc onprem shared mailbox sn11421 delegated l...
# 98050             linemax account extended till 10012026
# 98051  per user issue occured single email advise use...
#
# (98052, 2)
# No of Rows: 98052
#
# Number of columns in the dataset: 2

# %%
# Print column names 
print(df.columns,"\n")

# Print info on data types, non-nulls, memory usage etc.
print(df.info(),"\n")  

# Display summary statistics  
# Set display to show all rows and columns  
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Out:
# Index(['Summary', 'Resolution'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98052 entries, 0 to 98051
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Summary     98052 non-null  object
#  1   Resolution  98046 non-null  object
# dtypes: object(2)
# memory usage: 1.5+ MB
# None

# %%
# Print full summary statistics description
print(df.describe()) 

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())   

# Check duplicates
print("\nNumber of duplicate rows:")   
print(df.duplicated().sum())
# Out:
#             Summary                    Resolution
# count         98052                         98046
# unique         1554                         48624
# top     cloud issue  outlookemail profile created
# freq           8816                          1246
#
# Missing values per column:
# Summary       0
# Resolution    6
# dtype: int64
#
# Number of duplicate rows:
# 36790

# %% [markdown]
# #### Check for unique values

# %%
# Loop through each column in the DataFrame
for column in df.columns:
    unique_values = df[column].unique()
    unique_count = df[column].nunique()
    
    print(f"Column: {column}")
    print(f"Total Unique Values: {unique_count}")
    print(f"Unique Values: {unique_values}")
    print("-" * 40)


    # Print all unique values or limit to first N values if too many
    if unique_count > 20:  # You can change this limit based on your needs
        print(unique_values[:20])  # Print first 20 unique values only
        print("... (and more)")
    else:
        print(unique_values)
    
    print("-" * 40)
# Out:
# Column: Summary
# Total Unique Values: 1554
# Unique Values: ['asycuda issue 6 one user' 'email service available'
#  'oracle issue 7 one user' ... 'staff travel link mentioning display'
#  'hit desktop issue' 'agents information portal working']
# ----------------------------------------
# ['asycuda issue 6 one user' 'email service available'
#  'oracle issue 7 one user' 'pc related issues  airport' 'btp working'
#  'charika issue 6 one user' 'application working'
#  '2d barcode reader working' 'cloud issue desktop resource available'
#  'cute keyboard working airport' 'cloud issue'
#  'sabre crew management 6 minor functional users'
#  'document scanner issue cak' 'telephone working properly'
#  'bcps password reset' 'bpp working' 'skychain issue 7 one user'
#  'printer issue airport  laser network' 'document printer working'
#  'login related incident']
# ... (and more)
# ----------------------------------------
# Column: Resolution
# Total Unique Values: 48624
# Unique Values: ['cleared thinapp browder history' 'outlookemail profile created'
#  'refreshed session cleared browser' ...
#  'cdmc onprem shared mailbox sn11421 delegated list informed user raise email delegation request'
#  'linemax account extended till 10012026'
#  'per user issue occured single email advise user contact sd next attempt']
# ----------------------------------------
# ['cleared thinapp browder history' 'outlookemail profile created'
#  'refreshed session cleared browser' 'payment done'
#  'printer emulator restarted' 'instructions given' 'queue released'
#  'user confirmed issue sorted' 'power cable disconnected bgr devicereplug'
#  'dis reset vd' 'key board accepted system usb reset'
#  'oth user unable login via web browser internet slowness issue end user location advice user'
#  'due error crew data optimizer result copying work set live failed identifying erroneous data resolve issue updating crew select excluding 18055'
#  'btp paper guider installed properly fixed'
#  'bgr detect turned offon bgr done' 'restarted phone'
#  'inform user use ad password' 'apps response service restarted resolved'
#  'device error service restarted resolved' 'shipment loaded mercator']
# ... (and more)
# ----------------------------------------

# %% [markdown]
# Downloading NLTK package

# %%
import string
import nltk
from nltk.corpus import stopwords
# Download stopwords from NLTK
nltk.download('stopwords')

# %% [markdown]
# ### Handling missing values

# %% [markdown]
#  Convert to lowercase

# %%
# Fill NaN values in 'Summary' and 'Resolution' columns with empty strings
df['Summary'].fillna('', inplace=True)
df['Resolution'].fillna('', inplace=True)
# Convert 'Summary' and 'Resolution' columns to lowercase
df['Summary_lower'] = df['Summary'].str.lower()
df['Resolution_lower'] = df['Resolution'].str.lower()

# %% [markdown]
# Handle punctuation and stopwords

# %%
# Define a function to remove punctuation and stopwords
def preprocess_text(text):
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    # Tokenize the text into words
    words = text.split()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    # Join words back into a single string
    return ' '.join(words)

# %%
# Create new columns with preprocessed data
df['Preprocessed_Summary'] = df['Summary_lower'].apply(preprocess_text)
df['Preprocessed_Resolution'] = df['Resolution_lower'].apply(preprocess_text)

# %%
# Display the first few rows of the dataframe with new columns
print(df[['Summary', 'Preprocessed_Summary', 'Resolution', 'Preprocessed_Resolution']].head())
# Out:
#                       Summary       Preprocessed_Summary  \
# 0    asycuda issue 6 one user   asycuda issue 6 one user
# 1     email service available    email service available
# 2     oracle issue 7 one user    oracle issue 7 one user
# 3  pc related issues  airport  pc related issues airport
# 4                 btp working                btp working
#
#                           Resolution            Preprocessed_Resolution
# 0    cleared thinapp browder history    cleared thinapp browder history
# 1       outlookemail profile created       outlookemail profile created
# 2  refreshed session cleared browser  refreshed session cleared browser
# 3                       payment done                       payment done
# 4         printer emulator restarted         printer emulator restarted

# %%
# Save the modified dataframe with new columns to a CSV file (if needed)
#df.to_csv("D:\\User Data\\Oshadi\\USJ\\Acedemic\\3rd Year\\Sem 6\\Project\\Test1\\clean_and_encoding\\dataset\\question_and_answers_preprocessed.csv", index=False)
df.to_csv("New dataset\\incident_report_q&a_2.csv")

# %% [markdown]
#  Group by 'Summary' and find the most common resolution and fill missing values in 'Resolution'

# %%
import numpy as np


dataset = "New dataset\\incident_report_q&a_2.csv"
df = pd.read_csv(dataset, encoding='latin1') # if csv file in different directory add with correct path

# Print original DataFrame (for debugging)
print("Original DataFrame:")
print(df.head())

# Fill missing values in 'Resolution' based on the most common resolution for each summary
# Step 1: Group by 'Summary' and find the most common resolution
resolution_mode = df.groupby('Summary')['Resolution'].agg(lambda x: x.mode()[0] if not x.mode().empty else np.nan)

# Step 2: Map the most common resolution back to the original DataFrame
df['Resolution'] = df.apply(lambda row: resolution_mode[row['Summary']] if pd.isna(row['Resolution']) else row['Resolution'], axis=1)

# Optionally, you can also fill any remaining missing values with a specific value
# df['Resolution'].fillna('missing_resolution', inplace=True)

# Print modified DataFrame
print("\nModified DataFrame:")
print(df.head())
# Out:
# Original DataFrame:
#    Unnamed: 0                     Summary                         Resolution  \
# 0           0    asycuda issue 6 one user    cleared thinapp browder history
# 1           1     email service available       outlookemail profile created
# 2           2     oracle issue 7 one user  refreshed session cleared browser
# 3           3  pc related issues  airport                       payment done
# 4           4                 btp working         printer emulator restarted
#
#                 Summary_lower                   Resolution_lower  \
# 0    asycuda issue 6 one user    cleared thinapp browder history
# 1     email service available       outlookemail profile created
# 2     oracle issue 7 one user  refreshed session cleared browser
# 3  pc related issues  airport                       payment done
# 4                 btp working         printer emulator restarted
#
#         Preprocessed_Summary            Preprocessed_Resolution
# 0   asycuda issue 6 one user    cleared thinapp browder history
# 1    email service available       outlookemail profile created
# 2    oracle issue 7 one user  refreshed session cleared browser
# 3  pc related issues airport                       payment done
# 4                btp working         printer emulator restarted
#
# Modified DataFrame:
#    Unnamed: 0                     Summary                         Resolution  \
# 0           0    asycuda issue 6 one user    cleared thinapp browder history
# 1           1     email service available       outlookemail profile created
# 2           2     oracle issue 7 one user  refreshed session cleared browser
# 3           3  pc related issues  airport                       payment done
# 4           4                 btp working         printer emulator restarted
#
#                 Summary_lower                   Resolution_lower  \
# 0    asycuda issue 6 one user    cleared thinapp browder history
# 1     email service available       outlookemail profile created
# 2     oracle issue 7 one user  refreshed session cleared browser
# 3  pc related issues  airport                       payment done
# 4                 btp working         printer emulator restarted
#
#         Preprocessed_Summary            Preprocessed_Resolution
# 0   asycuda issue 6 one user    cleared thinapp browder history
# 1    email service available       outlookemail profile created
# 2    oracle issue 7 one user  refreshed session cleared browser
# 3  pc related issues airport                       payment done
# 4                btp working         printer emulator restarted

# %% [markdown]
# #### Save to new CSV (no missing values)

# %%
df.to_csv("New dataset\\incident_report_q&a_2_no_missings.csv", index=False)

# %% [markdown]
# #### Group by summery

# %% [markdown]
#  Get the Count of Summary Groups and Count and Print Different Summary Groups

# %%
import numpy as np
import pandas as pd

dataset = "New dataset\\incident_report_q&a_2_no_missings.csv"
df = pd.read_csv(dataset, encoding='latin1')  # Load CSV with latin1 encoding

# Group by 'Summary' and count the number of occurrences of each group
summary_counts = df.groupby('Summary').size()

# Print the summary groups and their counts
print("\nSummary Groups and Counts:")
print(summary_counts)

# Get the total number of unique 'Summary' groups
unique_summary_count = df['Summary'].nunique()

# Print the total count of unique 'Summary' groups
print(f"\nTotal number of unique Summary groups: {unique_summary_count}")

# Calculate the mode for the 'Resolution' within each 'Summary' group
resolution_mode = df.groupby('Summary')['Resolution'].agg(lambda x: x.mode()[0] if not x.mode().empty else np.nan)

# Fill missing 'Resolution' values with the mode from each 'Summary' group
df['Resolution'] = df.apply(lambda row: resolution_mode[row['Summary']] if pd.isna(row['Resolution']) else row['Resolution'], axis=1)
# Out:
# Summary Groups and Counts:
# Summary
# 12641 visible gal                                                                             1
# 17279 charika updates                                                                         1
# 2031153595 location airport counter 161                                                       1
# 2031153795 location airport counter 161                                                       1
# 2d barcode reader working                                                                   422
# 43 ul theme ip phones                                                                         1
# abi analyzer download error                                                                   1
# able connect ul vpn                                                                           1
# acars application issue                                                                       1
# acars issue                                                                                  10
# acars messages                                                                                1
# accelya team cannot connect remote pc                                                         1
# access blocked srilankancom due ip reputation user                                            1
# account disabled                                                                              1
# account getting locked frequently                                                             1
# acrs application issue                                                                        8
# activate inactive customer                                                                    1
# active sync eequest                                                                           1
# ad account created yet in1729                                                                 1
# ad folder issue top urgent                                                                    1
# ad password automatically changed                                                             1
# add names duty manager security ops group gal                                                 1
# add printer                                                                                   1
# add printers                                                                                  1
# adi issue                                                                                     1
# admin building network operation area entrance cctv camera working                            1
# adobe acrobat functioning correctly                                                           1
# adobe acrobat reader working                                                                 25
# aeroops application issue                                                                     2
# aeroops working                                                                               2
# agents information portal working                                                             1
# aims application issue                                                                        2
# aims issue                                                                                    2
# aims issue minor functional users                                                            11
# aims issue one user                                                                         640
# aims issue sitesection non critical                                                           7
# aims issue users                                                                              6
# aims password reset                                                                           1
# aims unable logon                                                                             1
# aims working                                                                                108
# airbus world issue                                                                            3
# airbus world issue 5 minor functionall users                                                  1
# airbus world issue 6 one user                                                                16
# airbus world working                                                                         52
# aircom issue                                                                                 17
# aircom issue flight tracking                                                                  1
# aircom issue g10 manager                                                                      1
# aircom issue minor functional users                                                           3
# aircom issue one user                                                                        23
# aircom issue sitesection non critical                                                         3
# aircom issue users                                                                            2
# aircom server globle alarm status alarm status red                                            1
# aircom working                                                                               88
# airfase issue                                                                                 2
# airfase issue 6 one user                                                                      3
# airfase working                                                                              34
# airline insight                                                                               1
# airline insight issue                                                                         1
# airline insight problem                                                                       1
# airline insight working                                                                      92
# airline insite                                                                                1
# airman issue 6 one user                                                                       6
# airman working                                                                                3
# airnav application issue                                                                     40
# airnav working                                                                              351
# airnw issue                                                                                   1
# airnw issue 6 one user                                                                       18
# airport printer working                                                                       1
# allow access emirates sharepoint                                                              1
# altea dcs issue                                                                              50
# altea ecommerce issue                                                                         2
# altea farespricing issue                                                                      4
# altea inv issue                                                                               4
# altea lssissue                                                                                5
# altea messagesmail messages                                                                   1
# altea restkt issue                                                                           56
# amadeus                                                                                       1
# amadeus altea admin issue                                                                     1
# amadeus altea customer management cm                                                          1
# amadeus altea customer management cm issue                                                   69
# amadeus altea customer management cm issue 1 users                                            5
# amadeus altea customer management cm issue 2 critical area user                               1
# amadeus altea customer management cm issue 4 sitesection non critical                         9
# amadeus altea customer management cm issue 5 minor functionall users                         10
# amadeus altea customer management cm issue 6 one user                                       432
# amadeus altea customer management cm working                                                125
# amadeus altea emd working                                                                     3
# amadeus altea flight management fm issue                                                     11
# amadeus altea flight management fm issue 4 sitesection non critical                           1
# amadeus altea flight management fm issue 5 minor functionall users                            1
# amadeus altea flight management fm issue 6 one user                                          52
# amadeus altea flight management fm working                                                   81
# amadeus altea ibe working                                                                    12
# amadeus altea inventory issue                                                                 3
# amadeus altea inventory issue 4 sitesection non critical                                      1
# amadeus altea inventory issue 6 one user                                                     25
# amadeus altea inventory working                                                              83
# amadeus altea logon security lss working                                                     12
# amadeus altea message net service issue 1 users                                               1
# amadeus altea message net service issue 4 sitesection non critical                            1
# amadeus altea message net service issue 5 minor functionall users                             2
# amadeus altea message net service issue 6 one user                                           36
# amadeus altea message net service working                                                     3
# amadeus altea online checkin working                                                         11
# amadeus altea password reset account sezgha43                                                 1
# amadeus altea reservation system working                                                    216
# amadeus altea web services working                                                            9
# amadeus coding notworking gcc                                                                 1
# amadeus dcs issue                                                                            17
# amadeus dcs issue critical area users                                                         1
# amadeus dcs issue one user                                                                    1
# amadeus emd issue                                                                             3
# amadeus end issue                                                                            12
# amadeus ibe issue                                                                             1
# amadeus login expiration                                                                      1
# amadeus messagenet portal issue                                                               1
# amadeus res issue                                                                            22
# amadeus res issue minor functional users                                                      7
# amadeus res issue one user                                                                   73
# amadeus res issue users                                                                       2
# amadeus res printing issue                                                                    1
# amadeus tty portal issue                                                                      1
# amos playground env working                                                                   1
# aors ghdr issue                                                                             232
# aors working                                                                                  4
# app issue ul counters                                                                         1
# application issue                                                                            10
# application issue password                                                                    1
# application outlook teams                                                                     1
# application request                                                                           8
# application request ise                                                                       1
# application working                                                                         308
# application working adobe pdf                                                                 1
# application working data scan                                                                 1
# application working filezilla                                                                 1
# application working iata reader                                                               1
# application working ie                                                                        1
# application working load manager gulf air                                                     1
# application working ms teams                                                                  1
# application working pdf                                                                       1
# application working pdf editor working                                                        1
# application working ping                                                                      1
# application working teams                                                                     1
# applications one intraneti server working                                                     1
# approval ref 490112 mr b n weldt requesting contractor long term pass fro                     1
# approval ref 490178 mr athugala requesting visitor day pass                                   1
# approval ref 491269 mr b n weldt requesting                                                   1
# approval ref 502455 mr p c fernando requesting visitor day pass 2710                          1
# approver change                                                                               1
# appsec issue fdca                                                                             1
# appsec issue government travel                                                                1
# aqd issue                                                                                     2
# aqd issue one user                                                                            4
# aqd working                                                                                  35
# aqderm working                                                                                5
# araksha issue                                                                                11
# araksha issue critical area users                                                             1
# araksha issue minor functional c4fk vd pool users                                             1
# araksha issue minor functional users                                                          2
# araksha issue one user                                                                      128
# araksha issue users                                                                           1
# araksha link available business application                                                   1
# araksha working                                                                              83
# ard link slow response                                                                        1
# ardintranet issue                                                                             1
# assign fingerprint                                                                            1
# asycuda application issue                                                                     4
# asycuda issue                                                                                 1
# asycuda issue 1 users                                                                         1
# asycuda issue 2 critical area user                                                            1
# asycuda issue 4 sitesection non critical                                                      1
# asycuda issue 6 one user                                                                     56
# asycuda working                                                                             134
# atpco working                                                                                25
# attendance issue                                                                              1
# audiocall conferance                                                                          1
# aura issue                                                                                   50
# aura issue minor functional users                                                             6
# aura issue one user                                                                         616
# aura issue sitesection non critical                                                           1
# aura issue users                                                                              1
# aura working                                                                               2290
# aura wvorking                                                                                 1
# authentic emails goes junkspam                                                                1
# auto call forwarding activation                                                               1
# aviation fuel working                                                                         6
# azure ftp server                                                                              1
# backup job issue                                                                              1
# baggage hand held scanner issue                                                               1
# baggage scanner issue                                                                         1
# baggage scanning issue fz bags                                                                1
# barcode                                                                                       1
# barcode reader working                                                                        1
# barcode readers                                                                               1
# bccs working                                                                                 11
# bcps issue                                                                                    1
# bcps issue 7 one use                                                                         10
# bcps issue minor functional users                                                             1
# bcps issue one user                                                                           7
# bcps password reset                                                                           1
# bcps working                                                                                 17
# bended intermittent inoperative cable                                                         1
# bo cfms working                                                                               1
# bo cris working                                                                               3
# bo fleetwatch working                                                                         5
# boarding gate readerairport                                                                   1
# boarding information display fids working airport                                             1
# boardpac working                                                                              7
# boardpacku meet issue 1 users                                                                 1
# boardpacku meet issue 3 senior manager                                                        1
# boardpacku meet issue 6 one user                                                              7
# bom ccas captured aug18                                                                       1
# bpp lounge invitation printing                                                                1
# bpp working                                                                                3159
# bpp working serendib lounge                                                                   1
# brs issue                                                                                    58
# brs issue 1 users                                                                             1
# brs issue 2 critical area user                                                                3
# brs issue 5 minor functionall users                                                           2
# brs issue 6 one user                                                                        126
# brs issue time stamp wrong reports brs                                                        1
# brs issue unable login system using common user id cmbbagservice                              1
# brs issue user loading performance report error                                               1
# brs issues refer dcs                                                                         60
# brs issues refer ultra                                                                       70
# brs password unlock                                                                           1
# brs record ul22518apr                                                                         1
# brs report aeroflotrussian airlines su                                                        1
# brs report air arabia g9                                                                      1
# brs vpn connectivity issue                                                                    1
# brs working                                                                                  17
# bsm issue                                                                                     1
# bsm issue cmb airport                                                                         1
# bsp hot files properly downloaded temporary area slp2021                                      1
# bsp link working                                                                              1
# btp working                                                                                2949
# budgetmate working                                                                            2
# business services working                                                                    76
# business services working printer issue                                                       1
# cabin crew voyage report loading discrepancies                                                1
# cabin crew voyage report meals                                                                1
# cable issue                                                                                   1
# cable neatening                                                                               1
# calendar share request                                                                        1
# call centre ivr issue 5 minor functionall users                                               1
# call diversion                                                                                1
# call divert option working properly                                                           1
# call forwarding                                                                               1
# cancelation ip phone transfer                                                                 1
# cannot access cmborul sita system                                                             1
# cannot log outlook                                                                            1
# cannt login                                                                                   1
# cant connect wifi                                                                            40
# cant login data scan online                                                                   1
# cant open outlook                                                                             1
# cant swap passport                                                                            2
# cant swap passport airport                                                                    1
# cant swap passports                                                                           5
# capa working                                                                                  8
# cargo agents feedback system issue 5 minor functionall users                                  1
# cargo charges issue 4 sitesection non critical                                                1
# cargo charges issue 6 one user                                                                8
# cargo flown data downloaded rapid                                                             1
# cargo max working                                                                             1
# cargo portal issue                                                                           16
# cargo portal issue 1 users                                                                    1
# cargo portal issue 2 critical area user                                                       1
# cargo portal issue 4 sitesection non critical                                                 2
# cargo portal issue 5 minor functionall users                                                  5
# cargo portal issue 6 one user                                                                25
# cargo portal working                                                                         84
# cargo rebate error                                                                            1
# cargo shift report                                                                            1
# cargo shift report issue                                                                      1
# cargo shift reportcsr working                                                                 9
# cargo warehouse system issue 6 one user                                                      25
# cargo warehouse working                                                                      24
# cargo wharehouse printing issue                                                               1
# cargochagers system issue                                                                     1
# case summary error gen2001financial month closing                                             1
# cca flown processedrevadjnot acctd may18                                                      1
# ccvr application issue                                                                      110
# ccvr issue                                                                                    1
# ccvr working                                                                                  1
# cfo laptop usb external adapter inoperative                                                   1
# cha                                                                                           1
# change extension display name                                                                 1
# change vlan                                                                                   1
# charika issue                                                                               178
# charika issue 1 users                                                                         8
# charika issue 3 senior manager                                                                1
# charika issue 4 sitesection non critical                                                      6
# charika issue 5 minor functionall users                                                       8
# charika issue 6 one user                                                                    536
# charika issue one user                                                                        1
# charika issue printing                                                                        1
# charika working                                                                             365
# chat bot working                                                                              1
# chrome working please install                                                                 1
# cisitacmblido1 router                                                                         1
# cloud device monitor                                                                          1
# cloud issue                                                                                8816
# cloud issue  printers                                                                       670
# cloud issue application issue                                                                 2
# cloud issue application working                                                               1
# cloud issue black screen                                                                    694
# cloud issue c drive full                                                                      1
# cloud issue cirtificate issue                                                                 7
# cloud issue cloud desktop maintenance                                                       265
# cloud issue cloud vd slow                                                                     1
# cloud issue count                                                                           370
# cloud issue data missing                                                                      1
# cloud issue desktop available                                                                 1
# cloud issue desktop resource available                                                     2362
# cloud issue desktop resource busy                                                            11
# cloud issue desktop resource busyble                                                          1
# cloud issue desktop resource responding                                                       1
# cloud issue device issue                                                                      1
# cloud issue disconnection                                                                   869
# cloud issue display protocol available                                                      360
# cloud issue display resoluation changed                                                       1
# cloud issue email issue                                                                       1
# cloud issue experiencing slowness                                                             1
# cloud issue getting stuck                                                                     1
# cloud issue h drive                                                                           2
# cloud issue keyboard issue                                                                    2
# cloud issue keyboard working                                                                  1
# cloud issue laptop                                                                            1
# cloud issue lido                                                                              1
# cloud issue login issue                                                                       1
# cloud issue login problem                                                                  1168
# cloud issue mouse issue                                                                       1
# cloud issue ms office issue                                                                   1
# cloud issue new staff                                                                         1
# cloud issue ost file location                                                                 1
# cloud issue outlook                                                                         784
# cloud issue pc automatically switching contact 2757 pc ulkbz2040                              1
# cloud issue power                                                                             2
# cloud issue preparing desktop                                                               326
# cloud issue session expired                                                                  22
# cloud issue session timeout                                                                   1
# cloud issue slow stuck                                                                      249
# cloud issue stuck wallpeper                                                                   1
# cloud issue stuck welcome screem                                                              1
# cloud issue trust relationship failure                                                       26
# cloud issue trust relationship issue                                                        216
# cloud issue user profile loaded                                                             375
# cloud issue vd responding                                                                     1
# cloud issue vd slowness                                                                       1
# cloud issue view agent issue                                                                  1
# cloud issue vm issue                                                                          1
# cloud issue vmware connection                                                                 1
# cloud issues                                                                                  1
# cloud login issue                                                                             1
# cloud request                                                                                 1
# cloud services                                                                                1
# cloud vd pool                                                                                 1
# cloudit access request                                                                        1
# cloudit account activation c13017                                                             1
# cloudit account creation sp6749                                                               1
# cloudit issue                                                                                69
# cloudit issue laptop                                                                          1
# cloudit issue pc slow unable get remote d09gen101                                             1
# cloudit issue zero client device locked user                                                  1
# cm mle                                                                                        1
# cmb cargo sls finger scanner unreachable 20311546140                                          1
# collect zc                                                                                    1
# comet working                                                                                 1
# communication issue satcom                                                                    1
# conference room freebusy presence available                                                   1
# connect board room projections                                                                1
# connected data cable resolved                                                                 1
# connection issue homs laptop                                                                  1
# connectivity brs dr server please see attached email                                          1
# converted pdf file                                                                            1
# cool room information display cargo working                                                   1
# corporate web sites issue                                                                    10
# corporate web sites issue 1 users                                                             4
# corporate web sites issue 2 critical area user                                                1
# corporate web sites issue 4 sitesection non critical                                          2
# corporate web sites issue 5 minor functionall users                                           6
# corporate web sites issue 6 one user                                                         53
# corporate web sites issue srilankancargocom                                                   1
# corporate website standard cr db                                                             94
# corporate website working                                                                    40
# correct email address                                                                         1
# cost center debits                                                                            1
# cou                                                                                           1
# couldnt resolved host name                                                                    1
# cps working                                                                                   1
# cr request                                                                                    1
# crash alarm socc                                                                              1
# create email account                                                                          1
# credit card                                                                                   1
# credit control application                                                                    1
# credit control system working                                                                 2
# crew control issue                                                                            1
# crew performance system issue 6 one user                                                      2
# crew space issue                                                                              4
# crew space issue 6 one user                                                                  24
# crew space working                                                                            4
# crew web application problem                                                                  1
# crewweb issue                                                                                11
# cris issue                                                                                    7
# cris issue 4 sitesection non critical                                                         1
# cris issue 7 one user                                                                        35
# cris working                                                                                 35
# crm working                                                                                   2
# cusdec engineering working                                                                   20
# cusdec issue 6 one user                                                                       5
# cute airlie application issue                                                               476
# cute application issue                                                                       23
# cute application related                                                                     11
# cute issue                                                                                   27
# cute issue 1 users                                                                            1
# cute issue 2 critical area                                                                    1
# cute issue 2 critical area user                                                               1
# cute issue 4 sitesection non critical                                                         1
# cute issue 5 minor functionall users                                                          1
# cute issue 6 one user                                                                        48
# cute keyboard related airport                                                               116
# cute keyboard working airport                                                              1592
# cute pc related  airport                                                                    211
# cute pc working load control                                                                  1
# data transmitting issue brs mobile scanners                                                   1
# database power bi                                                                             1
# dcs application issues                                                                      261
# dcs current version expire                                                                    1
# delete unnecessary shortcuts                                                                  1
# designation changesn 22975                                                                    1
# desktop issue                                                                                 1
# desktop support incident                                                                      2
# device related incident desktop pc                                                         1627
# device related incident device                                                               67
# device related incident emergency alarm nodes                                                 5
# device related incident fax machine                                                          66
# device related incident feedback device                                                      28
# device related incident finger scan machine                                                 118
# device related incident flight information display system fids                               25
# device related incident information display lfd                                              13
# device related incident ipad                                                                 26
# device related incident keyboard                                                            293
# device related incident kiosk machine                                                        19
# device related incident laptop                                                             1330
# device related incident mouse                                                               449
# device related incident multimedia projector                                                 61
# device related incident printer                                                            3194
# device related incident scanner                                                             437
# device related incident telephone                                                          1375
# device related incident thin client                                                         150
# device related incident walkie talkie                                                       183
# device related incident zero client                                                         457
# device relvaated incident desktop pc                                                          1
# device working                                                                               24
# dialog tv issue serenediva lounge                                                             1
# differences due rerouting lossgain jun18 rec                                                  1
# difficulty working laptop screen                                                              1
# digital publication                                                                           1
# disable smbv1                                                                                 1
# disk failure reported msa2040 storage model d2700 sas aj941a pa                               1
# display aocc                                                                                  1
# display screen issue lfd                                                                      1
# display working                                                                               1
# display working airport                                                                       1
# dms issue                                                                                     9
# dms issue 5 minor functionall users                                                           1
# dms issue 6 one user                                                                        122
# dms password reset                                                                            1
# dms working                                                                                  90
# dns service issue                                                                             1
# document printer                                                                              1
# document printer pc working                                                                   1
# document printer ramp working                                                                 1
# document printer working                                                                   2953
# document printer working cargo hub                                                            1
# document printer working security duty room                                                   1
# document scan issue airport                                                                   1
# document scanner issue airport                                                                4
# document scanner issue airport psu                                                            1
# document scanner issue apt                                                                    2
# document scanner issue cak                                                                  131
# document scanner issue cmb                                                                    5
# document scanner issue load control                                                           4
# document scanner issue pcu airport                                                            1
# document scanner issue serendib lounge                                                        1
# docusign issue                                                                                1
# docusign working                                                                              7
# door acces unit working                                                                       1
# door access control issue                                                                     1
# dpub issue                                                                                   18
# dpub issue 2 critical area user                                                               1
# dpub issue 5 minor functionall users                                                          1
# dpub issue 6 one user                                                                        59
# dpub working                                                                                264
# dubai visa link working                                                                       1
# due power failure                                                                             1
# duty free system issue                                                                       12
# duty free system issue back office systembos                                                  3
# duty free system issue mobile applicationpos                                                  8
# ...
# unable book nuwara eliya niwahana                                                             1
# unable check online                                                                           1
# unable check visas                                                                            1
# unable checking visa                                                                          1
# unable configure email laptop                                                                 1
# unable conn remoteapp                                                                         1
# unable connect cargo dr site cctv camera data centerhttp17231130                              1
# unable connect vd                                                                             1
# unable find emails                                                                            1
# unable find mails attached inbox                                                              1
# unable find mails inbox                                                                       1
# unable get remote login accylea                                                               1
# unable issue ticket                                                                           1
# unable log cmv2 remote application                                                            2
# unable login                                                                                  1
# unable login cloud                                                                            1
# unable login flista application using apple devices                                           1
# unable login it0011666 cont 1274                                                              1
# unable login kiosk                                                                            2
# unable login pc                                                                             557
# unable login sita net portal                                                                  1
# unable login win 10 vd                                                                        1
# unable login worldtracer users                                                                1
# unable open amadeus                                                                           1
# unable open file share pont                                                                   1
# unable open oracle                                                                            1
# unable payment staff ticket charika                                                           1
# unable provide remote support due temwewer authentication iaaue0                              1
# unable rdp 2031154133 server name it0009748                                                   1
# unable receive external emails                                                                1
# unable reset password                                                                         1
# unable run safari web report                                                                  1
# unable run scanner reports brs cloud                                                          1
# unable swap passports                                                                         3
# unable verify shipment                                                                        1
# unable view password                                                                          1
# unable work power bi                                                                          1
# undeliverable email                                                                           1
# unlocked account                                                                              1
# unreachable ip 57568420lido                                                                   1
# unread email count outlook incorrect                                                          1
# update department info intranet                                                               1
# upgrade plusgrade issue                                                                       1
# upgrade plusgrade issue 6 one user                                                            1
# ups power issue                                                                               1
# url httpsboardsrilankancom working                                                            1
# usb dogle instalation kbsl laptop                                                             1
# usb dongle issue                                                                              1
# uws gf14511mar                                                                                1
# vacbi technical training issue 6 one user                                                     3
# vd related issues                                                                             1
# veritas approvals showing                                                                     1
# veritas issue                                                                                 6
# veritas issue 6 one user                                                                      9
# veritas slow                                                                                  1
# veritas working                                                                              41
# vhf issue                                                                                     2
# vhf mcc working                                                                               1
# vhf radio equipment device error                                                              1
# vhf services                                                                                  1
# vhf working mcc                                                                               1
# view agent isuue                                                                              1
# virus h drive                                                                                 1
# virus suspicious activity                                                                     1
# visa check kiosk unservisable                                                                 1
# visa kiosk                                                                                    1
# visitor passes 489906                                                                         1
# vm ware version upgrade                                                                       1
# vmware                                                                                        1
# voyage report                                                                                 1
# vpls link failure colombo                                                                     1
# vpn issue                                                                                     5
# vulnerabilitty32tenable                                                                       1
# vulnerability alert cloud nessus                                                              3
# vulnerability alert infosec nessus                                                            2
# vulnerability alert nt server nessus                                                          2
# vulnerability alert pc                                                                        1
# vulnerability alert unix dba nessus                                                           9
# vulnerability alert unix dba nessus ulcakprddwbi                                              1
# vulnerability alert wan server nessus                                                         4
# vulnerability alert web server nessus                                                         2
# vulnerability cloud                                                                           1
# vulnerability kbsl                                                                            3
# vulnerability13tenable                                                                        1
# vulnerability16tenable                                                                        1
# vulnerability17tenable                                                                        1
# vulnerability19                                                                               1
# vulnerability20                                                                               1
# vulnerability21                                                                               1
# vulnerability25tenable                                                                        1
# vulnerability31 tenable                                                                       1
# vulnerability33tenable                                                                        1
# vulnerability34 tenable                                                                       1
# vulnerability35 tenable                                                                       1
# vulnerability37tenable                                                                        1
# vulnerability38 tenable                                                                       1
# vulnerability39tenable                                                                        1
# vulnerability40 tenable                                                                       1
# vulnerability42tenable                                                                        1
# vulnerability43tenable                                                                        1
# vulnerability44tenable                                                                        1
# vulnerability45tenable                                                                        1
# vulnerability46tenable                                                                        1
# vulnerability47tenable                                                                        1
# vulnerability48tenable                                                                        1
# vulnerability49tenable                                                                        1
# vulnerability50tenable                                                                        1
# vulnerability51tenable                                                                        1
# vulnerability52tenable                                                                        1
# vulnerability53tenable                                                                        1
# vulnerability54tenable                                                                        1
# vulnerability55tenable                                                                        1
# wackytacky vhf system                                                                         1
# walkietalkie issue 1 users                                                                    1
# walkietalkie issue 2 critical area user                                                       2
# walkietalkie issue 5 minor functionall users                                                  1
# walkietalkie issue 6 one user                                                                87
# warehouse                                                                                     1
# web mail login issue                                                                          1
# web production transfer automation working                                                    1
# web sites loading                                                                             1
# webfile transfer request                                                                   1256
# website working                                                                               1
# weighbridge application issue                                                                 4
# weighbridge issue 1 users                                                                     2
# weighbridge issue 4 sitesection non critical                                                  4
# weighbridge issue 5 minor functionall users                                                   4
# weighbridge issue 6 one user                                                                 60
# weighbridge issue users                                                                       1
# weighbridge working                                                                          22
# weight bridge issue                                                                           1
# weight printer                                                                                1
# wifi access issue                                                                             1
# wifi issue                                                                                    1
# wifi issue 3 senior manager                                                                   4
# wifi issue 4 sitesection non critical                                                         5
# wifi issue 5 minor functionall users                                                          2
# wifi issue 6 one user                                                                       376
# wifi issue serandiva                                                                          1
# wifi issue serendib lounge                                                                    1
# wifi issue serenediva lounge                                                                  1
# wifi issue serenediva serendib lounges                                                        1
# windows 10 laptop                                                                             1
# wire card working                                                                             1
# wise issue                                                                                    1
# working                                                                                    1477
# working charika                                                                               1
# working phishing mail                                                                         1
# workstations compliance report                                                                1
# world tracer                                                                                  1
# world tracer access                                                                           1
# world tracer working                                                                          2
# worldtracer issue 1 users                                                                     5
# worldtracer issue 4 sitesection non critical                                                  6
# worldtracer issue 5 minor functionall users                                                   6
# worldtracer issue 6 one user                                                                 70
# xperiencelog working                                                                          2
# youlink issue                                                                                 9
# youlink issue 4 sitesection non critical                                                      2
# youlink issue 5 minor functionall users                                                       3
# youlink issue 6 one user                                                                     20
# youlink issue external access                                                                 1
# youlink working                                                                              52
# zc related issues                                                                             1
# zebra printer working                                                                         1
# zeus working                                                                                  1
# dtype: int64
#
# Total number of unique Summary groups: 1554

# %% [markdown]
# Validate the Sum of Group Counts

# %%
# Sum of all counts in 'Summary' groups
total_group_counts = summary_counts.sum()

# Total number of rows in the dataset
total_rows = len(df)

# Validate that the sum of group counts equals the total number of rows
if total_group_counts == total_rows:
    print(f"\nSum of counts in each group ({total_group_counts}) matches the total number of rows ({total_rows}).")
else:
    print(f"\nMismatch: Sum of counts in each group ({total_group_counts}) does not match the total number of rows ({total_rows}).")
# Out:
# Sum of counts in each group (98052) matches the total number of rows (98052).

# %% [markdown]
# #### Create new question and answer dataset

# %%
import pandas as pd

# Select the required columns and rename them
df_new = df[['Preprocessed_Summary', 'Preprocessed_Resolution']].rename(
    columns={'Preprocessed_Summary': 'Summary', 'Preprocessed_Resolution': 'Resolution'}
)

# Save the new dataset (optional)
df_new.to_csv("New dataset\\incident_report_q&a", index=False)

# Display the first few rows
print(df_new.head())

# %% [markdown]
# #### Explore new question and answer dataset

# %%
import pandas as pd
dataset="d:\\User Data\\Oshadi\\USJ\\Acedemic\\3rd Year\\Sem 6\\Project\\Test1\\clean_and_encoding\\dataset\\New dataset\\incident_report_q&a.csv"
df = pd.read_csv(dataset, encoding='latin1') 


print(df.shape) #see number of rows and columns
num_rows = df.shape[0]
print("No of Rows: " + str(df.shape[0])+"\n")
num_columns = df.shape[1]
print("Number of columns in the dataset:", num_columns,"\n")

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# (98052, 2)
# No of Rows: 98052
#
# Number of columns in the dataset: 2
#
#
# Missing values per column:
# Summary       0
# Resolution    6
# dtype: int64

# %% [markdown]
# #### Check duplicates in new dataset

# %%
# Check duplicates
print("\nNumber of duplicate rows:")   
print(df.duplicated().sum())
# Out:
# Number of duplicate rows:
# 36790

# %% [markdown]
# #### Remove duplicates and handle if missing values occured

# %%
import pandas as pd

# Load the dataset
dataset="d:\\User Data\\Oshadi\\USJ\\Acedemic\\3rd Year\\Sem 6\\Project\\Test1\\clean_and_encoding\\dataset\\New dataset\\incident_report_q&a.csv"
df = pd.read_csv(dataset, encoding='latin1') 
# Display initial information about the dataset
initial_info = {
    "initial_shape": df.shape,
    "columns": df.columns.tolist(),
    "missing_values": df.isnull().sum(),
    "duplicates_count": df.duplicated().sum()
}
# 1. Remove duplicate rows
df = df.drop_duplicates()
# 2. Handle missing values by dropping rows with missing data
df = df.dropna()
# 3. Text cleaning: convert text to lowercase, remove punctuation, and strip whitespace
df['Summary'] = df['Summary'].str.lower().str.replace(r'[^\w\s]', '', regex=True).str.strip()
df['Resolution'] = df['Resolution'].str.lower().str.replace(r'[^\w\s]', '', regex=True).str.strip()
# Display final shape and sample data after preprocessing
final_info = {
    "final_shape": df.shape,
    "sample_data": df.head()
}

initial_info, final_info
# Out:
# ({'initial_shape': (98052, 2),
#   'columns': ['Summary', 'Resolution'],
#   'missing_values': Summary       0
#   Resolution    6
#   dtype: int64,
#   'duplicates_count': 36790},
#  {'final_shape': (61256, 2),
#   'sample_data':                       Summary                         Resolution
#   0    asycuda issue 6 one user    cleared thinapp browder history
#   1     email service available       outlookemail profile created
#   2     oracle issue 7 one user  refreshed session cleared browser
#   3  pc related issues  airport                       payment done
#   4                 btp working         printer emulator restarted})

# %% [markdown]
# #### Final Dataset for Question and Answering

# %%
# Save the cleaned dataset to a new CSV file
output_path = 'd:\\User Data\\Oshadi\\USJ\\Acedemic\\3rd Year\\Sem 6\\Project\\Test1\\clean_and_encoding\\dataset\\New dataset\\incident_report_q&a_cleaned.csv'
df.to_csv(output_path, index=False)

print("File saved as:", output_path)

# %% [markdown]
# #### Explore Final Full Question and Answering

# %%
import pandas as pd
dataset="d:\\User Data\\Oshadi\\USJ\\Acedemic\\3rd Year\\Sem 6\\Project\\Test1\\clean_and_encoding\\dataset\\New dataset\\incident_report_q&a_cleaned.csv"
df = pd.read_csv(dataset, encoding='latin1') 


print(df.shape) #see number of rows and columns
num_rows = df.shape[0]
print("No of Rows: " + str(df.shape[0])+"\n")
num_columns = df.shape[1]
print("Number of columns in the dataset:", num_columns,"\n")

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())   

# Check duplicates
print("\nNumber of duplicate rows:")   
print(df.duplicated().sum())
# Out:
# (61256, 2)
# No of Rows: 61256
#
# Number of columns in the dataset: 2
#
#
# Missing values per column:
# Summary       0
# Resolution    0
# dtype: int64
#
# Number of duplicate rows:
# 0
